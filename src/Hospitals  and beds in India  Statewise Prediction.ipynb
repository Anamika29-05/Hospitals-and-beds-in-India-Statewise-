# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv(r"C:\Users\anami\Downloads\archive (4)\Hospitals_and_Beds_statewise.csv")
df.head()
# Out:
#                   Unnamed: 0   PHC  CHC  SDH  DH Total Unnamed: 6
# 0  Andaman & Nicobar Islands    27    4  NaN   3    34       1246
# 1             Andhra Pradesh  1417  198   31  20  1666      60799
# 2          Arunachal Pradesh   122   62  NaN  15   199       2320
# 3                      Assam  1007  166   14  33  1220      19115
# 4                      Bihar  2007   63   33  43  2146      17796

# %%
df = pd.read_csv(r"C:\Users\anami\Downloads\archive (4)\Employees State Insurance Corporation .csv")
df.head()
# Out:
#   Employees State Insurance Corporation Hospitals and beds (as on 31.03.2017)  \
# 0                                             S. No.
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#           Unnamed: 1             Unnamed: 2         Unnamed: 3
# 0        States /UTs  Total No. of Hospital  Total No. of Beds
# 1     Andhra Pradesh                      5                345
# 2              Assam                      1                 75
# 3              Bihar                      3                 50
# 4  Chandigarh [Adm.]                      1                 70

# %%
df = pd.read_csv(r"C:\Users\anami\Downloads\archive (4)\Hospitals and Beds maintained by Ministry of Defence.csv")
df.head()
# Out:
#   S. No.              Name of State  No. of Hospitals  No. of beds
# 0      1                      Assam               8.0       2357.0
# 1      2             Andhra Pradesh               1.0        306.0
# 2      3  Andaman & Nicobar Islands               1.0        107.0
# 3      4          Arunachal Pradesh               1.0        198.0
# 4      5                      Bihar               2.0        348.0

# %%
df = pd.read_csv(r"C:\Users\anami\Downloads\archive (4)\Hospitals and beds maintained by Railways.csv")
df.head()
# Out:
#   Number of Hospitals and beds in Railways (as on 21/03/2018)  \
# 0                                              S.No.
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#              Unnamed: 1              Unnamed: 2                Unnamed: 3
# 0             Zone / PU  Total No. of Hospitals  Total No. of Indoor Beds
# 1       Central Railway                      11                      1164
# 2       Eastern Railway                       8                      1587
# 3  East central Railway                       9                       819
# 4    East coast Railway                       4                       339

# %%
df = pd.read_csv(r"C:\Users\anami\Downloads\archive (4)\Hospitals.csv")
df.head()
# Out:
#   Srl no.         State / UT Number of Hospitals  Unnamed: 3 Unnamed: 4  \
# 0     NaN                NaN               Govt.  Local Body     Others
# 1      -1                 -2                  -3          -4         -5
# 2       1     Andhra Pradesh                   8           0          0
# 3       2  Arunachal Pradesh                  11           0          1
# 4       3              Assam                   4           0          0
#
#   Unnamed: 5 Number of Beds  Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0      Total          Govt.  Local Body     Others      Total
# 1         -6             -7          -8         -9        -10
# 2          8            365           0          0        365
# 3         12            100           0         25        125
# 4          4            205           0          0        205

# %%
df = pd.read_csv(r"C:\Users\anami\Downloads\archive (4)\Number of Government Hospitals and Beds in Rural and Urban Areas .csv")
df.head()
# Out:
#            States/UTs Rural hospitals Unnamed: 2 Urban hospitals Unnamed: 4  \
# 0                 NaN             No.       Beds             No.       Beds
# 1      Andhra Pradesh             193       6480              65      16658
# 2  Arunachal Pradesh*             208       2136              10        268
# 3               Assam            1176      10944              50       6198
# 4               Bihar             930       6083             103       5936
#
#         As on
# 0         NaN
# 1  01.01.2017
# 2  31.12.2017
# 3  31.12.2017
# 4  31.12.2016

# %%
df = df.rename(columns={'Unnamed: 0':'State', 'Unnamed: 6':'Beds'})
df.head()
# Out:
#   Srl no.         State / UT Number of Hospitals  Unnamed: 3 Unnamed: 4  \
# 0     NaN                NaN               Govt.  Local Body     Others
# 1      -1                 -2                  -3          -4         -5
# 2       1     Andhra Pradesh                   8           0          0
# 3       2  Arunachal Pradesh                  11           0          1
# 4       3              Assam                   4           0          0
#
#   Unnamed: 5 Number of Beds  Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0      Total          Govt.  Local Body     Others      Total
# 1         -6             -7          -8         -9        -10
# 2          8            365           0          0        365
# 3         12            100           0         25        125
# 4          4            205           0          0        205

# %%
X = np.random.rand(100, 4)  # Example feature matrix with 100 samples and 4 features
y = np.random.randint(0, 2, 100)  # Example binary target variable

# Now split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
 
model = RandomForestRegressor(n_estimators=200, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("📈 Model Performance:")
print(f"MAE  : {mae:.2f}")
print(f"RMSE : {rmse:.2f}")
print(f"R²   : {r2:.2f}\n")
# Out:
# 📈 Model Performance:
# MAE  : 0.51
# RMSE : 0.53
# R²   : -0.24

# %%
plt.figure(figsize=(6,4))
plt.scatter(y_test, y_pred, color='royalblue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Actual Beds")
plt.ylabel("Predicted Beds")
plt.title("Actual vs Predicted Beds")
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['States/UTs', 'Rural hospitals', 'Unnamed: 2', 'Urban hospitals', 'Unnamed: 4', 'As on']
